# %% [markdown]
# # Task 1.1
# With List Comp
#
# get_titles(movies)
#
# Output
# ["Inception", "Interstellar", "Dunkirk", "The Dark Knight", "Memento"]

# %%
movies = [
    {
        "title": "Inception",
        "ratings": [5, 4, 5, 4, 5]
    },
    {
        "title": "Interstellar",
        "ratings": [5, 5, 4, 5, 4]
    },
    {
        "title": "Dunkirk",
        "ratings": [4, 4, 4, 3, 4]
    },
    {
        "title": "The Dark Knight",
        "ratings": [5, 5, 5, 5, 5]
    },
    {
        "title": "Memento",
        "ratings": [4, 5, 4, 5, 4]
    },
]

def get_ratings(movies):
    return [movie['title'] for movie in movies]

print(get_ratings(movies))

# %%
movies = [
    {
        "title": "Inception",
        "ratings": [5, 4, 5, 4, 5]
    },
    {
        "title": "Interstellar",
        "ratings": [5, 5, 4, 5, 4]
    },
    {
        "title": "Dunkirk",
        "ratings": [4, 4, 4, 3, 4]
    },
    {
        "title": "The Dark Knight",
        "ratings": [5, 5, 5, 5, 5]
    },
    {
        "title": "Memento",
        "ratings": [4, 5, 4, 5, 4]
    },
]
def get_ratings(movies):
    return [sum(movie['ratings'])/len(movie['ratings']) for movie in movies]
print(get_ratings(movies))

# %%
guests = [
    {"name": "Alice", "age": 25, "code": "VIP123"},
    {"name": "Bob", "age": 17, "code": "VIP123"},
    {"name": "Charlie", "age": 30, "code": "VIP123"},
    {"name": "Dave", "age": 22, "code": "GUEST"},
    {"name": "Eve", "age": 29, "code": "VIP123"},
]

blacklist = ["Dave", "Eve"]

PASS_CODE = "VIP123"
result = [
    guest["name"]
    for guest in guests
    if guest["age"] >= 21
    and guest["code"] == PASS_CODE
    and guest["name"] not in blacklist
]
print(result)

# %%
val = []
for guest in guests:
    if (
        guest["age"] >= 21
        and guest["code"] == PASS_CODE
        and guest["name"] not in blacklist
    ):
        val.append(guest["name"])
print(val)

# %%
books = [
    {
        "title": "Python Programming",
        "author": "Eric Matthes",
        "year": 2019,
        "available": True,
    }
]

user_input = int(input("Please choose an option:"))
while user_input == 1:
    def add_book(books):
        title = input("Please tell me the title?  ")
        author = input("Please tell me the author?  ")
        year = input("Please tell me the year?  ")
        available = input("Please tell me the available?  ")
        books.append(
        {"title": title, "year": author, "year": year, "available": available}
        )
        print("Main menu: ")
        print("1. Add book to the library  ")
        print("2. Print all the books ")
        print("3. Exit  ")
        user_input = int(input("Please choose an option 2:"))   
        if user_input == 2:
            return books
            # continue   # print
        elif user_input == 3:
            print("Bye 😄👋  ")
        else:
             continue
add_book(books)

# %%
books = [
    {
        "title": "Python Programming",
        "author": "Eric Matthes",
        "year": 2019,
        "available": True,
    }
]


def add_book():
    title = input("Please tell me the title?  ")
    author = input("Please tell me the author?  ")
    year = int(input("Please tell me the year?  "))
    available = input("Please tell me the available? (Y/N) ").upper() == "Y"

    books.append(
    {"title": title, "author": author, "year": year, "available": available}
    )
    return "Successfully added 😄✅" 

def print_books(books):
    return books

def exit_book_app():
    return False

def main():    
    condition =  True
    while condition:
        print("Main menu: 📒")
        print("1. Add book to the library  ")
        print("2. Print all the books ")
        print("3. Exit  ")
        user_input = int(input("Please choose an option:"))
        
        if user_input == 1:
            print(add_book())
        elif user_input == 2:
            print(print_books(books))
        elif user_input == 3:
            print("bye 🙋‍♂️👋")
            # condition = exit_book_app()
            break
        else:
            print("Invalid Key 👎 Enter between 1 - 3")
                
main()
# Out:
# Main menu: 📒
# 1. Add book to the library
# 2. Print all the books
# 3. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 48
#      45         else:
#      46             print("Invalid Key 👎 Enter between 1 - 3")
# ---> 48 main()
#
# Cell In[13], line 35, in main()
#      33 print("2. Print all the books ")
#      34 print("3. Exit  ")
# ---> 35 user_input = int(input("Please choose an option:"))
#      37 if user_input == 1:
#      38     print(add_book())
#
# ValueError: invalid literal for int() with base 10: ''
